# %%
#Imports:
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../analysisTools/")
import plotTools as ptools
import utils

# %%
#coffea output file -- SIGNAL
f_sig = "../coffea/skimmed/example_signal_skimmed_SR.coffea"

sig_histo = util.load(f_sig) [0]

#utils.get_signal_list_of_histograms(sig_histo)

# %%
#coffea output file -- BACKGROUND
bkg_f = "../coffea/skimmed/example_bkg_skimmed_SR.coffea"

bkg_histo = util.load(bkg_f)[0]

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'MET_pt',
    'cut' : 'cut10',
    'year' : 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 2j,
    'xlim': [200,1000],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim' : None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    #'xlabel': r"dPhi (MET, leading jet)",
    'xlabel': r"MET pT ",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': '../plots/bkg',
    'outName': f'no logbackground_cut4_metpt.png'
}

ptools.plot_bkg_1d(ax,bkg_histo, plot_dict, style_dict, isLegacy = False)
#style_dict['label'] = 'V+ jets'
#ptools.plot_bkg_1d_stacked(ax,bkg_histo, plot_dict, style_dict, isLegacy = False,processes=['WJets','ZJets'])

#style_dict['label'] = 'All backgrounds'
#ptools.plot_bkg_1d_stacked(ax,bkg_histo, plot_dict, style_dict, isLegacy = False,processes='all')

plt.title('')
plt.legend()
plt.show()

# %% [markdown]
# **2D background plots**

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

plot_dict = {
    'variable': 'sel_vtx_mass_vs_vxy',
    'cut': 'cut4',
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 2j,
    'yrebin': 2j,
    'xlim': [0,20],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': [0,10],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': False,
    'xlabel':r"mass",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$L_{xy}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'nologbackground_cut4_mass_vs_Lxy.png'
}

ptools.plot_bkg_2D(ax,bkg_histo, plot_dict, style_2d_dict,isLegacy = False, processes = 'all')
# Out:
# Saved: ./plots//nologbackground_cut4_mass_vs_Lxy.png

# %% [markdown]
# **Signal 2D plots**

# %%
# Plot settings
m1 = 30
delta = 0.1
ctau = 10
fig, ax = plt.subplots(figsize=(7,7))

plot_dict = {
    'variable': 'sel_vtx_mass_vs_vxy',
    'cut': 'cut9',
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': [0,10],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': [0,10],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': False,
    'xlabel': r"mass",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$L_{xy}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'signal_cut9_nolog_m1_{m1}_delta_{delta}_ctau_{ctau}.png'
}

ptools.plot_signal_2D(ax, sig_histo, m1, delta, ctau, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots//signal_cut9_nolog_m1_30_delta_0.1_ctau_10.png
