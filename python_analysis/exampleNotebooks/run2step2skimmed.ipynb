# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../analysisTools/")
import plotTools as ptools
import utils

# %%
#coffea output file
f_bkg = "../coffea/skimmed/skimmed_WJets_2018_compare.coffea"

#Nested Dictionary:
bkg_histo = util.load(f_bkg) [0]
for i in bkg_histo.keys():
    print(i)
# Out:
# sel_e1_pt
# sel_e1_eta
# sel_e1_phi
# sel_e1_dxy
# sel_e1_dxySignif
# sel_e1_miniRelIso
# sel_e1_miniRelIsoCorr
# sel_e1_mindRJets
# sel_e1_isPF
# sel_e1_passConvVeto
# sel_e1_IDscore
# sel_e2_pt
# sel_e2_eta
# sel_e2_phi
# sel_e2_dxy
# sel_e2_dxySignif
# sel_e2_miniRelIso
# sel_e2_miniRelIsoCorr
# sel_e2_mindRJets
# sel_e2_isPF
# sel_e2_passConvVeto
# sel_e2_IDscore
# sel_e1e2_type
# sel_vtx_dR
# sel_vtx_mindxy
# sel_vtx_vxy1
# sel_vtx_vxy10
# sel_vtx_vxy100
# sel_vtx_leadpT
# sel_vtx_METdPhi
# sel_vtx_mindRj
# sel_vtx_chi2
# sel_vtx_mass
# sel_vtx_mass_low
# sel_vtx_mass_refit
# sel_vtx_mass_low_refit
# sel_vtx_mindPhiJ
# sel_vtx_sign
# sel_vtx_pt
# sel_vtx_eta
# sel_vtx_phi
# sel_vtx_type
# sel_vtx_minEleDrJ
# sel_vtx_minEleDPhiJ
# sel_vtx_mindxy_low
# sel_vtx_sign_etaProd
# sel_vtx_CosThetaColl
# sel_vtx_LxyCosThetaColl
# sel_vtx_LxyCosThetaCollZoom
# sel_vtx_LxyCosThetaCollZoomZoom
# sel_vtx_eleDphi
# sel_vtx_maxMiniRelIso
# sel_vtx_maxMiniRelIsoCorr
# sel_vtx_e1e2PassConvVeto
# sel_vtx_vx_vs_vy
# sel_vtx_mass_vs_vxy
# sel_vtx_mass_vs_vxy20
# sel_vtx_vxyRes
# sel_vtx_vxySignif
# sel_vtx_vxy20_vs_vxyRes
# sel_vtx_vxy20_vs_vxySignif
# PFMET
# jetMETdPhi
# minJetMETdPhi
# nJets
# lead_jet_pt
# lead_jet_eta
# jetMETratio
# bdtscore
# cutDesc
# cutflow
# cutflow_cts
# cutflow_nevts
# cutflow_vtx_matched

# %%
#Description of the cuts
cuts = list(bkg_histo["cutDesc"].keys())  #The cuts
print (cuts)
# Out:
# ['all', 'hasVtx', 'cut1', 'cut2', 'cut3', 'cut4', 'cut5', 'cut6', 'cut7', 'cut8', 'cut9', 'cut10']

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_vxy100',
    'cut': 'cut1',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,20],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"Lxy (in cm)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_sel_vtx_vxy100.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# /uscms/home/reshmar/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/skimmed/WJets_sel_vtx_vxy100.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass_refit',
    'cut': 'cut3',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,10],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "sel_vtx_mass_refit",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_mass_030.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_mass_030.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass_low',
    'cut': 'cut2',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,1] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "Invariant mass of di-electrons (in GeV)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_INVARIANT_sel_vtx_mass_low.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_INVARIANT_sel_vtx_mass_low.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass_low_refit',
    'cut': 'cut2',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,1] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "Refit Invariant mass of di-electrons (in GeV)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_sel_vtx_mass_low_refit.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_sel_vtx_mass_low_refit.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass_low_refit',
    'cut': 'cut2',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,1] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "sel_vtx_mass_low",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_sel_vtx_mass_low.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_sel_vtx_mass_low.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'PFMET',
    'cut': 'cut1',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,500] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "$E_T$ miss",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_nJets.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_nJets.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_phi',
    'cut': 'cut1',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[-3.5,3.5] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "phi (in radians)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'PHI_WJets_sel_vtx_phi.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/PHI_WJets_sel_vtx_phi.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'jetMETdPhi',
    'cut': 'cut8',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,6] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "jetMETdPhi",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_jetMETdPhi.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_jetMETdPhi.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'minJetMETdPhi',
    'cut': 'cut1',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,6] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "minJetMETdPhi",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_minJetMETdPhi.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_minJetMETdPhi.png
