# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../analysisTools/")
from analysisTools import Analyzer
from analysisTools import iDMeProcessor
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os

# %% [markdown]
# **Run coffea on skimmed ntuples**

# %%
sample_config = "../configs/sample_configs/WJets2022.json"   

cuts_config = "../configs/cut_configs/unskimmed_SR_BDT.py" 

histos_config = "../configs/histo_configs/histos_SR.py"

# %%
outdir = "../coffea/unskimmed/"
os.makedirs(outdir, exist_ok=True)

# %%
#sample_config = "../configs/sample_configs/skimmed_bkg/skimmed_bkg_2018_v7_miniAOD_noNJetCut.json"
analyzer = Analyzer(sample_config, histos_config, cuts_config) 

#analyzer = iDMeProcessor(sample_config,sample_config,sample_config, histos_config, cuts_config) 

t1 = time.time()
out = analyzer.process(execr="iterative")
#out = analyzer.process(execr='futures')
t2 = time.time()

#print("Runtime: {:.2f} minutes".format((t2-t1)/60))
util.save(out,f"{outdir}/WJets_2022.coffea")

#del out, analyzer
# Out:
# Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/1 [ 0:00:16 < 0:00:00 | ? chunk/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
print(out)
# Out:
# ({'sel_e1_pt': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(50, 0, 50, name='pt'),
#   storage=Weight()) # Sum: WeightedSum(value=9.31853, variance=0.123388) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e1_eta': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -2.5, 2.5, name='eta'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e1_phi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(64, -3.2, 3.2, name='phi'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e1_dxy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='dxy'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e1_dxySignif': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 20, name='signif'),
#   storage=Weight()) # Sum: WeightedSum(value=9.34393, variance=0.123709) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e1_miniRelIso': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=9.2921, variance=0.123038) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e1_miniRelIsoCorr': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=9.31884, variance=0.123395) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e1_mindRJets': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=8.89672, variance=0.117826) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e1_isPF': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='isPF'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e1_passConvVeto': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='passVeto'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e1_IDscore': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -1, 3, name='id'),
#   storage=Weight()) # Sum: WeightedSum(value=8.44116, variance=0.111721) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e2_pt': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(50, 0, 50, name='pt'),
#   storage=Weight()) # Sum: WeightedSum(value=8.78772, variance=0.116341) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e2_eta': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -2.5, 2.5, name='eta'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e2_phi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(64, -3.2, 3.2, name='phi'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e2_dxy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='dxy'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e2_dxySignif': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 20, name='signif'),
#   storage=Weight()) # Sum: WeightedSum(value=9.37028, variance=0.124056) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e2_miniRelIso': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=9.34531, variance=0.123746) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e2_miniRelIsoCorr': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=9.34531, variance=0.123746) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e2_mindRJets': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=9.02607, variance=0.119499) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e2_isPF': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='isPF'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e2_passConvVeto': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='passVeto'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_e2_IDscore': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -1, 3, name='id'),
#   storage=Weight()) # Sum: WeightedSum(value=9.21071, variance=0.121935) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_e1e2_type': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   StrCategory(['L', 'R'], name='e1type'),
#   StrCategory(['L', 'R'], name='e2type'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_dR': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=9.37182, variance=0.124098) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_mindxy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='dxy'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_vxy1': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 1, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=5.07626, variance=0.0671294) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_vxy10': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 10, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=9.15982, variance=0.121288) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_vxy100': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(1000, 0, 100, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_leadpT': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(50, 0, 50, name='pt'),
#   storage=Weight()) # Sum: WeightedSum(value=8.70858, variance=0.115297) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_METdPhi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_mindRj': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=8.7921, variance=0.116458) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_chi2': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='chi2'),
#   storage=Weight()) # Sum: WeightedSum(value=2.24233, variance=0.0295867) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_mass': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(300, 0, 300, name='mass'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_mass_refit': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 30, name='mass_refit'),
#   storage=Weight()) # Sum: WeightedSum(value=8.6057, variance=0.113973) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_mindPhiJ': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_sign': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([-1, 1], name='sign'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_pt': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 100, name='pt'),
#   storage=Weight()) # Sum: WeightedSum(value=9.37115, variance=0.12408) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_eta': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -2.5, 2.5, name='eta'),
#   storage=Weight()) # Sum: WeightedSum(value=8.84606, variance=0.117185) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_phi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(64, -3.2, 3.2, name='phi'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_type': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   StrCategory(['LL', 'LR', 'RR'], name='vtype'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_minEleDrJ': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=9.212, variance=0.121969) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_minEleDPhiJ': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_mass_low': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='mass_low'),
#   storage=Weight()) # Sum: WeightedSum(value=2.69821, variance=0.0356996) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_mindxy_low': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(1000, 0, 0.1, name='mindxy_low'),
#   storage=Weight()) # Sum: WeightedSum(value=9.31877, variance=0.123394) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_sign_etaProd': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([-1, 1], name='sign_etaProd'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_CosThetaColl': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -1, 1, name='cosTheta'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_LxyCosThetaColl': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -50, 50, name='LxyCosTheta'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_LxyCosThetaCollZoom': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -5, 5, name='LxyCosThetaZoom'),
#   storage=Weight()) # Sum: WeightedSum(value=8.70639, variance=0.11524) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_LxyCosThetaCollZoomZoom': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -1, 1, name='LxyCosThetaZoomZoom'),
#   storage=Weight()) # Sum: WeightedSum(value=5.63119, variance=0.0744637) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_eleDphi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_maxMiniRelIso': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=9.2656, variance=0.122687) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_maxMiniRelIsoCorr': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=9.29233, variance=0.123044) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_e1e2PassConvVeto': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='passVeto'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'sel_vtx_vx_vs_vy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(300, -15, 15, name='vx'),
#   Regular(300, -15, 15, name='vy'),
#   storage=Weight()) # Sum: WeightedSum(value=9.31806, variance=0.123375) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_mass_vs_vxy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='mass_low'),
#   Regular(100, 0, 10, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=2.48716, variance=0.032915) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_mass_vs_vxy20': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='mass_low'),
#   Regular(200, 0, 20, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=2.64527, variance=0.0349988) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_vxyRes': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='vxyRes'),
#   storage=Weight()) # Sum: WeightedSum(value=9.37148, variance=0.124089) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_vxySignif': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 50, name='vxySignif'),
#   storage=Weight()) # Sum: WeightedSum(value=3.42707, variance=0.045187) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_vxy20_vs_vxyRes': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(200, 0, 20, name='vxy'),
#   Regular(100, 0, 5, name='vxyRes'),
#   storage=Weight()) # Sum: WeightedSum(value=9.34474, variance=0.123731) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'sel_vtx_vxy20_vs_vxySignif': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(200, 0, 20, name='vxy'),
#   Regular(500, 0, 50, name='vxySignif'),
#   storage=Weight()) # Sum: WeightedSum(value=3.40088, variance=0.0448439) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'PFMET': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 50, 300, name='met'),
#   storage=Weight()) # Sum: WeightedSum(value=3.99751, variance=0.0529302) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'jetMETdPhi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'minJetMETdPhi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'nJets': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(10, 0, 10, name='nJets'),
#   storage=Weight()) # Sum: WeightedSum(value=9.39768, variance=0.124432), 'lead_jet_pt': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 80, 1000, name='jet_pt'),
#   storage=Weight()) # Sum: WeightedSum(value=0.690229, variance=0.00916456) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'lead_jet_eta': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -2.5, 2.5, name='eta'),
#   storage=Weight()) # Sum: WeightedSum(value=5.74472, variance=0.076068) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'jetMETratio': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 2, name='jetMETratio'),
#   storage=Weight()) # Sum: WeightedSum(value=7.59661, variance=0.100573) (WeightedSum(value=9.39768, variance=0.124432) with flow), 'bdtscore': Hist(
#   StrCategory([], growth=True, name='samp', label='Sample Name'),
#   StrCategory([], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 1, name='bdtscore'),
#   storage=Weight()) # Sum: WeightedSum(value=0, variance=0), 'cutDesc': defaultdict(<class 'str'>, {'all': 'No cuts', 'hasVtx': 'Baseline Selection', 'cut1': 'Pass MET Filters', 'cut2': 'HEM Veto', 'cut4': 'MET > 200 GeV', 'cut6': 'Leading jet pT > 80 GeV', 'cut7': 'Leading jet |eta| < 2.4', 'cut8': 'dPhi(MET,leading jet) > 2.0', 'cut9': 'dPhi(MET,all jets) > 0.75', 'cut10': 'BDT'}), 'cutflow': {'bkg_2022_WJets': defaultdict(<class 'float'>, {'all': 1.0, 'hasVtx': 0.010216621673751427, 'cut1': 0.010216621673751427, 'cut2': 0.010216621673751427, 'cut4': 0.0, 'cut6': 0.0, 'cut7': 0.0, 'cut8': 0.0, 'cut9': 0.0, 'cut10': 0.0})}, 'cutflow_cts': {'bkg_2022_WJets': defaultdict(<class 'float'>, {'all': 459.92099999999994, 'hasVtx': 4.698838856813429, 'cut1': 4.698838856813429, 'cut2': 4.698838856813429, 'cut4': 0.0, 'cut6': 0.0, 'cut7': 0.0, 'cut8': 0.0, 'cut9': 0.0, 'cut10': 0.0})}, 'cutflow_nevts': {'bkg_2022_WJets': defaultdict(<class 'int'>, {'all': 34760, 'hasVtx': 355, 'cut1': 355, 'cut2': 355, 'cut4': 0, 'cut6': 0, 'cut7': 0, 'cut8': 0, 'cut9': 0, 'cut10': 0})}, 'cutflow_vtx_matched': {'bkg_2022_WJets': defaultdict(<class 'float'>, {})}}, {'bytesread': 9225350, 'columns': ['vtx_sign', 'LptElectron_dRJets', 'PFJet_pt', 'Electron_dxyErr', 'LptElectron_pt', 'nPFJet', 'vtx_dPhiJets', 'vtx_refit_phi', 'vtx_refit_pt', 'LptElectron_isPF', 'vtx_eta', 'genWgt', 'Electron_IDcutLoose', 'vtx_e2_idx', 'LptElectron_dxy', 'Electron_dPhiJets', 'PV_y', 'vtx_vy', 'vtx_e2_typ', 'LptElectron_phi', 'vtx_vxy', 'vtx_px', 'vtx_METdPhi', 'nElectron', 'vtx_typ', 'vtx_reduced_chi2', 'LptElectron_miniRelIsoEleCorr', 'vtx_e1_idx', 'PFJet_METdPhi', 'Electron_isPF', 'Electron_eta', 'vtx_refit_m', 'LptElectron_conversionVeto', 'vtx_vx', 'Electron_miniRelIso', 'METFiltersFailBits', 'nvtx', 'LptElectron_ID', 'LptElectron_miniRelIso', 'vtx_pt', 'PFJet_phi', 'LptElectron_eta', 'Electron_pt', 'vtx_phi', 'vtx_e1_typ', 'vtx_sigmavxy', 'Electron_phi', 'vtx_e1_refit_dxy', 'vtx_dR', 'PV_x', 'Electron_conversionVeto', 'Electron_dxy', 'PFJet_eta', 'PFMET_pt', 'Electron_miniRelIsoEleCorr', 'LptElectron_dxyErr', 'Electron_dRJets', 'vtx_py', 'LptElectron_dPhiJets', 'vtx_dRJets', 'vtx_e2_refit_dxy', 'nLptElectron', 'vtx_m'], 'entries': 34760, 'processtime': 14.806638240814209, 'chunks': 1})
