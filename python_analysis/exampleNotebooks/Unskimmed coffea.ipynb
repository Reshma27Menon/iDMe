# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../analysisTools/")
from analysisTools import Analyzer
from analysisTools import iDMeProcessor
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os

# %% [markdown]
# **Run coffea on skimmed ntuples**

# %%
sample_config = "../configs/sample_configs/WJets2022.json"   

cuts_config = "../configs/cut_configs/unskimmed_SR_BDT.py" 

histos_config = "../configs/histo_configs/histos_SR.py"

# %%
outdir = "../coffea/unskimmed/"
os.makedirs(outdir, exist_ok=True)

# %%
#sample_config = "../configs/sample_configs/skimmed_bkg/skimmed_bkg_2018_v7_miniAOD_noNJetCut.json"
analyzer = Analyzer(sample_config, histos_config, cuts_config) 

#analyzer = iDMeProcessor(sample_config,sample_config,sample_config, histos_config, cuts_config) 

t1 = time.time()
out = analyzer.process(execr="iterative")
#out = analyzer.process(execr='futures')
t2 = time.time()

#print("Runtime: {:.2f} minutes".format((t2-t1)/60))
util.save(out,f"{outdir}/WJets_2022.coffea")

#del out, analyzer
# Out:
# Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/1 [ 0:00:14 < 0:00:00 | ? chunk/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
print(out)
# Out:
# ({'sel_e1_pt': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(50, 0, 50, name='pt'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e1_eta': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -2.5, 2.5, name='eta'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e1_phi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(64, -3.2, 3.2, name='phi'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e1_dxy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='dxy'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e1_dxySignif': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 20, name='signif'),
#   storage=Weight()) # Sum: WeightedSum(value=11.6843, variance=0.268878) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_e1_miniRelIso': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=11.6844, variance=0.268881) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_e1_miniRelIsoCorr': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e1_mindRJets': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=11.0399, variance=0.25404) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_e1_isPF': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='isPF'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e1_passConvVeto': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='passVeto'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e1_IDscore': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -1, 3, name='id'),
#   storage=Weight()) # Sum: WeightedSum(value=10.3608, variance=0.23866) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_e2_pt': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(50, 0, 50, name='pt'),
#   storage=Weight()) # Sum: WeightedSum(value=11.181, variance=0.25736) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_e2_eta': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -2.5, 2.5, name='eta'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e2_phi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(64, -3.2, 3.2, name='phi'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e2_dxy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='dxy'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e2_dxySignif': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 20, name='signif'),
#   storage=Weight()) # Sum: WeightedSum(value=11.5942, variance=0.266846) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_e2_miniRelIso': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e2_miniRelIsoCorr': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e2_mindRJets': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=11.2262, variance=0.258384) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_e2_isPF': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='isPF'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e2_passConvVeto': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='passVeto'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_e2_IDscore': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -1, 3, name='id'),
#   storage=Weight()) # Sum: WeightedSum(value=11.6417, variance=0.267977) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_e1e2_type': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   StrCategory(['L', 'R'], name='e1type'),
#   StrCategory(['L', 'R'], name='e2type'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_dR': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_mindxy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='dxy'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_vxy1': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 1, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=5.98188, variance=0.137694) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_vxy10': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 10, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=11.4528, variance=0.263513) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_vxy100': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(1000, 0, 100, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_leadpT': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(50, 0, 50, name='pt'),
#   storage=Weight()) # Sum: WeightedSum(value=11.181, variance=0.25736) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_METdPhi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_mindRj': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=11.0858, variance=0.255095) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_chi2': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='chi2'),
#   storage=Weight()) # Sum: WeightedSum(value=2.11436, variance=0.0486091) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_mass': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(300, 0, 300, name='mass'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_mass_refit': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 30, name='mass_refit'),
#   storage=Weight()) # Sum: WeightedSum(value=10.8979, variance=0.250682) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_mindPhiJ': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_sign': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([-1, 1], name='sign'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_pt': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 100, name='pt'),
#   storage=Weight()) # Sum: WeightedSum(value=11.6412, variance=0.267954) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_eta': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -2.5, 2.5, name='eta'),
#   storage=Weight()) # Sum: WeightedSum(value=11.3686, variance=0.261752) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_phi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(64, -3.2, 3.2, name='phi'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_type': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   StrCategory(['LL', 'LR', 'RR'], name='vtype'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_minEleDrJ': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='dR'),
#   storage=Weight()) # Sum: WeightedSum(value=11.5005, variance=0.264653) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_minEleDPhiJ': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_mass_low': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='mass_low'),
#   storage=Weight()) # Sum: WeightedSum(value=3.67693, variance=0.0845414) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_mindxy_low': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(1000, 0, 0.1, name='mindxy_low'),
#   storage=Weight()) # Sum: WeightedSum(value=11.6391, variance=0.267855) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_sign_etaProd': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([-1, 1], name='sign_etaProd'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_CosThetaColl': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -1, 1, name='cosTheta'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_LxyCosThetaColl': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -50, 50, name='LxyCosTheta'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_LxyCosThetaCollZoom': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -5, 5, name='LxyCosThetaZoom'),
#   storage=Weight()) # Sum: WeightedSum(value=10.9953, variance=0.253044) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_LxyCosThetaCollZoomZoom': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -1, 1, name='LxyCosThetaZoomZoom'),
#   storage=Weight()) # Sum: WeightedSum(value=6.57626, variance=0.151287) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_eleDphi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_maxMiniRelIso': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=11.6844, variance=0.268881) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_maxMiniRelIsoCorr': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='iso'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_e1e2PassConvVeto': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   IntCategory([0, 1], name='passVeto'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_vx_vs_vy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(300, -15, 15, name='vx'),
#   Regular(300, -15, 15, name='vy'),
#   storage=Weight()) # Sum: WeightedSum(value=11.5915, variance=0.26672) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_mass_vs_vxy': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='mass_low'),
#   Regular(100, 0, 10, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=3.49037, variance=0.0801864) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_mass_vs_vxy20': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 5, name='mass_low'),
#   Regular(200, 0, 20, name='vxy'),
#   storage=Weight()) # Sum: WeightedSum(value=3.63171, variance=0.0835186) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_vxyRes': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 5, name='vxyRes'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'sel_vtx_vxySignif': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(500, 0, 50, name='vxySignif'),
#   storage=Weight()) # Sum: WeightedSum(value=4.05031, variance=0.0932527) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_vxy20_vs_vxyRes': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(200, 0, 20, name='vxy'),
#   Regular(100, 0, 5, name='vxyRes'),
#   storage=Weight()) # Sum: WeightedSum(value=11.6396, variance=0.267878) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'sel_vtx_vxy20_vs_vxySignif': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(200, 0, 20, name='vxy'),
#   Regular(500, 0, 50, name='vxySignif'),
#   storage=Weight()) # Sum: WeightedSum(value=4.05031, variance=0.0932527) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'PFMET': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 50, 300, name='met'),
#   storage=Weight()) # Sum: WeightedSum(value=4.83109, variance=0.111195) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'jetMETdPhi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'minJetMETdPhi': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 3.2, name='abs_dphi'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'nJets': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(10, 0, 10, name='nJets'),
#   storage=Weight()) # Sum: WeightedSum(value=11.7315, variance=0.269989), 'lead_jet_pt': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 80, 1000, name='jet_pt'),
#   storage=Weight()) # Sum: WeightedSum(value=1.00743, variance=0.0230757) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'lead_jet_eta': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, -2.5, 2.5, name='eta'),
#   storage=Weight()) # Sum: WeightedSum(value=7.9208, variance=0.18247) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'jetMETratio': Hist(
#   StrCategory(['bkg_2022_WJets'], growth=True, name='samp', label='Sample Name'),
#   StrCategory(['cut1', 'cut2'], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 2, name='jetMETratio'),
#   storage=Weight()) # Sum: WeightedSum(value=9.88724, variance=0.227452) (WeightedSum(value=11.7315, variance=0.269989) with flow), 'bdtscore': Hist(
#   StrCategory([], growth=True, name='samp', label='Sample Name'),
#   StrCategory([], growth=True, name='cut', label='Cut Applied'),
#   Regular(100, 0, 1, name='bdtscore'),
#   storage=Weight()) # Sum: WeightedSum(value=0, variance=0), 'cutDesc': defaultdict(<class 'str'>, {'all': 'No cuts', 'hasVtx': 'Baseline Selection', 'cut1': 'Pass MET Filters', 'cut2': 'HEM Veto', 'cut4': 'MET > 200 GeV', 'cut6': 'Leading jet pT > 80 GeV', 'cut7': 'Leading jet |eta| < 2.4', 'cut8': 'dPhi(MET,leading jet) > 2.0', 'cut9': 'dPhi(MET,all jets) > 0.75', 'cut10': 'BDT'}), 'cutflow': {'bkg_2022_WJets': defaultdict(<class 'float'>, {'all': 1.0, 'hasVtx': 0.012753783377603802, 'cut1': 0.012753783377603802, 'cut2': 0.012753783377603802, 'cut4': 0.0, 'cut6': 0.0, 'cut7': 0.0, 'cut8': 0.0, 'cut9': 0.0, 'cut10': 0.0})}, 'cutflow_cts': {'bkg_2022_WJets': defaultdict(<class 'float'>, {'all': 459.92099999999994, 'hasVtx': 5.865732804810917, 'cut1': 5.865732804810917, 'cut2': 5.865732804810917, 'cut4': 0.0, 'cut6': 0.0, 'cut7': 0.0, 'cut8': 0.0, 'cut9': 0.0, 'cut10': 0.0})}, 'cutflow_nevts': {'bkg_2022_WJets': defaultdict(<class 'int'>, {'all': 20000, 'hasVtx': 255, 'cut1': 255, 'cut2': 255, 'cut4': 0, 'cut6': 0, 'cut7': 0, 'cut8': 0, 'cut9': 0, 'cut10': 0})}, 'cutflow_vtx_matched': {'bkg_2022_WJets': defaultdict(<class 'float'>, {})}}, {'bytesread': 5365974, 'columns': ['Electron_IDcutLoose', 'Electron_conversionVeto', 'LptElectron_dRJets', 'Electron_dRJets', 'nElectron', 'vtx_e2_typ', 'vtx_e2_idx', 'vtx_e2_refit_dxy', 'vtx_vx', 'PV_y', 'PFJet_pt', 'LptElectron_dPhiJets', 'vtx_refit_pt', 'vtx_px', 'Electron_dxy', 'PFMET_pt', 'LptElectron_isPF', 'LptElectron_miniRelIsoEleCorr', 'nPFJet', 'PFJet_eta', 'vtx_dR', 'Electron_eta', 'vtx_e1_refit_dxy', 'vtx_METdPhi', 'PV_x', 'LptElectron_miniRelIso', 'Electron_isPF', 'vtx_pt', 'vtx_reduced_chi2', 'LptElectron_ID', 'vtx_typ', 'PFJet_METdPhi', 'Electron_miniRelIso', 'LptElectron_dxy', 'METFiltersFailBits', 'vtx_dRJets', 'LptElectron_pt', 'LptElectron_conversionVeto', 'vtx_e1_idx', 'LptElectron_dxyErr', 'LptElectron_eta', 'LptElectron_phi', 'vtx_sign', 'Electron_miniRelIsoEleCorr', 'vtx_vxy', 'vtx_eta', 'nvtx', 'nLptElectron', 'vtx_e1_typ', 'vtx_dPhiJets', 'vtx_refit_m', 'vtx_vy', 'vtx_m', 'Electron_phi', 'Electron_dxyErr', 'vtx_refit_phi', 'genWgt', 'vtx_phi', 'Electron_dPhiJets', 'Electron_pt', 'vtx_sigmavxy', 'PFJet_phi', 'vtx_py'], 'entries': 20000, 'processtime': 12.381225347518921, 'chunks': 1})
